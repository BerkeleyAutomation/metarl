# %% [markdown]
# Training for 40,000 time steps before the representation is saved.
#
# starts = [(-2, 0.8, 0, 2.5), (1.3,0.6, 0, -1.5), (-1.3,-.4, 0, 0.15), (1.5,-1.97, 0, -1.45), (0.6,-1.9, 0, -0.8), ]

# %%
% matplotlib notebook 
from agentdistribution import *

# %%
agents = ['./GeneratedAgents/RCCarConfidence/Domains.RCCarModified/Jul11_06-51-369621',
 './GeneratedAgents/RCCarConfidence/Domains.RCCarModified/Jul11_06-54-712478',
 './GeneratedAgents/RCCarConfidence/Domains.RCCarModified/Jul11_06-54-981478',
 './GeneratedAgents/RCCarConfidence/Domains.RCCarModified/Jul11_06-55-419938',
 './GeneratedAgents/RCCarConfidence/Domains.RCCarModified/Jul12_06-56-228023']

# %%
distribution = [sample_state_distribution(a_path) for a_path in agents]
# Out:
# [INFO] Loading agent from ./GeneratedAgents/RCCarConfidence/Domains.RCCarModified/Jul11_06-51-369621/params.yml
# Loaded rbfs_sigma
# Loaded weight_vec
# Loaded rbfs_mu
# 65.0 36 True -4.95740693983
# 66.0 35 True -4.94675867479
# 66.0 35 True -4.94675867479
# 65.0 36 True -4.95740693983
# 22.0 79 True -4.99999710127
# 67.0 34 True -4.93344834349
# 67.0 34 True -4.93344834349
# 64.0 37 True -4.96592555187
# 67.0 34 True -4.93344834349
# 64.0 37 True -4.96592555187
# 18.0 83 True -4.99999881268
# 65.0 36 True -4.95740693983
# 67.0 34 True -4.93344834349
# 66.0 35 True -4.94675867479
# 67.0 34 True -4.93344834349
# 66.0 35 True -4.94675867479
# 66.0 35 True -4.94675867479
# 67.0 34 True -4.93344834349
# 67.0 34 True -4.93344834349
# 68.0 33 True -4.91681042936
# 67.0 34 True -4.93344834349
# 66.0 35 True -4.94675867479
# 67.0 34 True -4.93344834349
# 65.0 36 True -4.95740693983
# 67.0 34 True -4.93344834349
# 67.0 34 True -4.93344834349
# 66.0 35 True -4.94675867479
# ...

# %%
from Domains import RCCarModified

# %%
domain = RCCarModified()

# %%
% matplotlib notebook
domain.showStateDistribution(distribution, ['r', 'b', 'brown', 'purple', 'black'])
# Out:
# <img src="data:image/png;base64,...">

# %%
from scipy import stats
import matplotlib.pyplot as plt
test_dist = distribution[3].T[:2]
kde1 = stats.gaussian_kde(test_dist)
kde1.set_bandwidth(bw_method=kde1.factor * 4
                 )
kde1.evaluate([-2.,-1.])
# Out:
# array([  6.42039179e-77])

# %%
m1, m2 = test_dist
xmin = m1.min()
xmax = m1.max()
ymin = m2.min()
ymax = m2.max()
X, Y = np.mgrid[-2.5:2.5:100j, -2:2:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
Z = np.reshape(kde1.evaluate(positions).T, X.shape)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,
          extent=[-2.5, 2.5, -2, 2])
ax.plot(m1, m2, 'k.', markersize=2)
ax.set_xlim([-2.5, 2.5])
ax.set_ylim([-2, 2])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# Out:
# array([  1.10224489e-243])

# %%
kde = state_distribution_model(agents[0])
# Out:
# [INFO] Loading agent from ./GeneratedAgents/RCCarConfidence/Domains.RCCarModified/Jul11_06-51-369621/params.yml
# Loaded rbfs_sigma
# Loaded weight_vec
# Loaded rbfs_mu

# %%
kde.evaluate([-1.0,0])
# Out:
# array([ 1.80519748])
