# %%
import scipy.stats as stats
import numpy as np
x1 = np.array([-7, -5, 1, 4, 5.])
kde = stats.gaussian_kde(x1)
xs = np.linspace(-10, 10, num=50)
y1 = kde(xs)
kde.set_bandwidth(bw_method='silverman')
y2 = kde(xs)
print kde.factor
kde.set_bandwidth(bw_method=kde.factor * 10
                 )
y3 = kde(xs)
# Out:
# 0.767703899275

# %%
% matplotlib notebook 

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(x1, np.ones(x1.shape) / (4. * x1.size), 'bo',
        label='Data points (rescaled)')
# ax.plot(xs, y1, label='Scott (default)')
# ax.plot(xs, y2, label='Silverman')
ax.plot(xs, y3, label='Const (1/3 * Silverman)')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# For each RBF node, given state $s$
#
#
# $$\vec{x} = (s - \mu) \odot (\vec{\sigma ^{-1}})$$
#
# Previously, was set as $$ 0.5 \|x \| ^2 $$. Now, set as
# $$ (x)^T A (x) $$

# %% [markdown]
# How do we do exploration by q value submission

# %%
# List of results

"./Results/DiffAgents/VotingUpdateMaha/Jul20_05-28-728740 "

trained_agents = ['./GeneratedAgents/RCCarConfidenceMaha/Domains.RCCarModified/Jul20_05-31-150183',
                  './GeneratedAgents/RCCarConfidenceMaha/Domains.RCCarModified/Jul20_05-58-800284',
                  './GeneratedAgents/RCCarConfidenceMaha/Domains.RCCarModified/Jul20_05-34-499485',
                  './GeneratedAgents/RCCarConfidenceMaha/Domains.RCCarModified/Jul20_05-35-425587',
                  './GeneratedAgents/RCCarConfidenceMaha/Domains.RCCarModified/Jul20_05-36-215566']
