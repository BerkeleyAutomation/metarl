# %%
import numpy as np
import pickle as p
import csv
from datetime import datetime

# %%
import rlpy.Tools.results as rt

paths = {'Eps=0.10': '/home/jarvis/work/clipper/models/rl/GeneratedAgents/RCCar/Jul09_04-24-006536',
 'Eps=0.15': '/home/jarvis/work/clipper/models/rl/GeneratedAgents/RCCar/Jul09_05-36-174173',
 'Eps=0.20': '/home/jarvis/work/clipper/models/rl/GeneratedAgents/RCCar/Jul09_05-36-710932',
 'Eps=0.25': '/home/jarvis/work/clipper/models/rl/GeneratedAgents/RCCar/Jul09_05-44-639012',
 'Eps=0.30': '/home/jarvis/work/clipper/models/rl/GeneratedAgents/RCCar/Jul09_05-44-236315',
 'Voting-Init-5': '/home/jarvis/work/clipper/models/rl/Results/DiffAgents/VotingUpdate/Jul09_06-49-891051',
 'Voting-Eps-5': '/home/jarvis/work/clipper/models/rl/Results/DiffAgents/VotingUpdate/Jul09_08-13-040253',
 'Voting-Eps-10': '/home/jarvis/work/clipper/models/rl/Results/DiffAgents/VotingUpdate/Jul09_07-30-700599',
 'Voting-Eps-20': '/home/jarvis/work/clipper/models/rl/Results/DiffAgents/VotingUpdate/Jul09_08-13-055519',
 'Voting-Exp5': '/home/jarvis/work/clipper/models/rl/Results/Confidence2/Jul16_06-03-308493/'
}

# %%
r = rt.MultiExperimentResults(paths) 
keys = r.data.keys()
# print  r.data['Voting-Eps5'].values()

# %%
# data = dict((k, r.data[k][1]['return']) for k in keys)
data = dict((k, r.data[k].values()[0]['return']) for k in keys)

# %%
def movingavg(arr, period, filt):
    return [filt(arr[i:i + period]) for i in range(len(arr) - period + 1)]

# %%
import matplotlib.pyplot as plt
% matplotlib notebook

# %%
# plt.figure()
per = 1
avg_data = dict((k, movingavg(v, per, np.median)) for k, v in data.items())
steps = r.data[keys[0]].values()[0]['learning_steps'][per - 1:]

for k, v in avg_data.items():
    plt.plot(steps,v,label=k)

plt.show()
plt.title("Evaluations".format(per))
plt.legend(loc=1, bbox_to_anchor=(0.1, 1), prop={'size':10})
# Out:
# <img src="data:image/png;base64,...">

# %%
#Voting only 

% matplotlib notebook
# plt.figure()
per = 10

avg_data = dict((k, movingavg(v, per, np.mean)) for k, v in data.items())
steps = r.data[keys[0]].values()[0]['learning_steps'][per - 1:]


for k, v in avg_data.items():
    if k[0] == 'E':
        plt.plot(steps,v,label=k)

plt.show()
plt.title("Individual: Mean of past {} evaluations".format(per))
plt.legend(loc=1, bbox_to_anchor=(0.1, 1), prop={'size':10})

plt.figure()

avg_data = dict((k, movingavg(v, per, np.median)) for k, v in data.items())
steps = r.data[keys[0]].values()[0]['learning_steps'][per - 1:]


for k, v in avg_data.items():
    if k[0] == 'E':
        plt.plot(steps,v,label=k)

plt.show()
plt.title("Individual: Median of past {} evaluations".format(per))
plt.legend(loc=1, bbox_to_anchor=(0.1, 1), prop={'size':10})
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
#Voting only 

% matplotlib notebook
# plt.figure()
per = 5

avg_data = dict((k, movingavg(v, per, np.mean)) for k, v in data.items())
steps = r.data[keys[0]].values()[0]['learning_steps'][per - 1:]


for k, v in avg_data.items():
    if k[0] == 'V':
        plt.plot(steps,v,label=k)

plt.show()
plt.title("Voting: Mean of past {} evaluations".format(per))
plt.legend(loc=1, bbox_to_anchor=(0.1, 1), prop={'size':10})

plt.figure()

avg_data = dict((k, movingavg(v, per, np.median)) for k, v in data.items())
steps = r.data[keys[0]].values()[0]['learning_steps'][per - 1:]


for k, v in avg_data.items():
    if k[0] == 'V':
        plt.plot(steps,v,label=k)

plt.show()
plt.title("Voting: Median of past {} evaluations".format(per))
plt.legend(loc=1, bbox_to_anchor=(0.1, 1), prop={'size':10})
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
#Voting only 

% matplotlib notebook
# plt.figure()
per = 5

avg_data = dict((k, movingavg(v, per, np.mean)) for k, v in data.items())
steps = r.data[keys[0]].values()[0]['learning_steps'][per - 1:]


for k, v in avg_data.items():
    if k[-1] == '5' and k[0] == 'V':
        plt.plot(steps,v,label=k)

plt.show()
plt.title("Voting: Mean of past {} evaluations".format(per))
plt.legend(loc=1, bbox_to_anchor=(0.1, 1), prop={'size':10})

plt.figure()

avg_data = dict((k, movingavg(v, per, np.median)) for k, v in data.items())
steps = r.data[keys[0]].values()[0]['learning_steps'][per - 1:]


for k, v in avg_data.items():
    if k[-1] == '5' and k[0] == 'V':
        plt.plot(steps,v,label=k)

plt.show()
plt.title("Voting: Median of past {} evaluations".format(per))
plt.legend(loc=1, bbox_to_anchor=(0.6, 1), prop={'size':10})
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
#Voting only 

% matplotlib notebook
# plt.figure()
per = 10
avg_data = dict((k, movingavg(v, per, np.median)) for k, v in data.items())
steps = r.data[keys[0]].values()[0]['learning_steps'][per - 1:]


for k, v in avg_data.items():
    plt.plot(steps,v,label=k)

plt.show()
plt.title("Median of past {} evaluations".format(per))
plt.legend(loc=1, bbox_to_anchor=(0.1, 1), prop={'size':10})
# Out:
# <img src="data:image/png;base64,...">
