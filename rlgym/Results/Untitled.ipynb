# %%
% matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

x = [4, 6, 7, 8, 10, 12, 16]
mean_y = np.array([-483, -502.25, -554.36, -667, -720.15, -782.69, -896.54])
plt.plot(x, mean_y, '-o')
# ax.bar(x, abs(mean_y))
